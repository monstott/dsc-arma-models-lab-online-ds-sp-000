# %% [markdown]
# # ARMA Models - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge the Autoregressive (AR), the Moving Average (MA) model, and the combined ARMA model.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Understand and explain what a Autoregressive model is
# - Understand and explain what a Moving Average model is
# - Understand and apply the mathematical formulations for Autoregressive and Moving Average models
# - Understand how AR and MA can be combined in ARMA models

# %% [markdown]
# ## Generate an AR model of the first order with $\phi = 0.7$

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Recall that the AR model has the following formula:
#
# $$Y_t = \mu + \phi * Y_{t-1}+\epsilon_t$$
#
# This means that:
#
# $$Y_1 = \mu + \phi * Y_{0}+\epsilon_1$$
# $$Y_2 = \mu + \phi * (\text{mean-centered version of } Y_1) +\epsilon_2$$
#
# and so on.
#
# Assume a mean-zero white noise with a standard deviation of 2. Make sure you have a daily datetime index ranging from January 2017 until the end of March 2018. Assume that $\mu=5$ and $Y_0= 8$.

# %%
# keep the random seed
np.random.seed(11225)

# create a series with the specified dates
dates = pd.date_range('2017-01-01', '2018-03-31')
len(dates)
# Out:
# 455

# %%
# store the parameters
mu = 5
phi = 0.7
Y_0 = 8
error = np.random.normal(0, 2, len(dates))

# %%
# generate the time series according to the formula
TS = [None] * len(dates)
y = Y_0
for i, row in enumerate(dates):
    TS[i] = mu + phi * y + error[i]
    y = TS[i] - mu

# %% [markdown]
# Plot the time series and verify what you see

# %%
# plot here
series = pd.Series(TS, index=dates)
series.plot(figsize=(12, 6), linewidth=2, fontsize=14);

# %% [markdown]
# ## Look at the ACF and PACF of your model and write down your conclusions

# %% [markdown]
# We recommend to use `plot_acf` in statsmodels instead of the pandas ACF variant.

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

fig, ax = plt.subplots(figsize=(14, 4))
plot_acf(series, ax=ax, lags=40);

fig, ax = plt.subplots(figsize=(14, 4))
plot_pacf(series, ax=ax, lags=40);

# %% [markdown]
# ## Check your model with ARMA in statsmodels

# %% [markdown]
# Statsmodels also has a tool that fits ARMA models on time series. The only thing you have to do is provide the number of orders for AR vs MA. Have a look at the code below, and the output of the code. Make sure that the output for the $\phi$ parameter and $\mu$ is as you'd expect!

# %%
# assuming your time series are stored in an object "series"
# Import the ARMA module from statsmodels
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm

# Fit an MA(1) model to the first simulated data
mod_arma = ARMA(series, order=(1,0))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())

# Print out the estimate for the constant and for theta
print(res_arma.params)
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  455
# Model:                     ARMA(1, 0)   Log Likelihood                -968.698
# Method:                       css-mle   S.D. of innovations              2.033
# Date:                Thu, 07 Nov 2019   AIC                           1943.395
# Time:                        13:27:37   BIC                           1955.756
# Sample:                    01-01-2017   HQIC                          1948.265
#                          - 03-31-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.9664      0.269     18.444      0.000       4.439       5.494
# ar.L1.y        0.6474      0.036     17.880      0.000       0.576       0.718
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.5446           +0.0000j            1.5446            0.0000
# -----------------------------------------------------------------------------
# const      4.966376
# ar.L1.y    0.647429
# dtype: float64

# %% [markdown]
# ## Generate an MA model of the first order with $\theta = 0.9$

# %% [markdown]
# Recall that the MA model has the following formula:
#
# $$Y_t = \mu +\epsilon_t + \theta * \epsilon_{t-1}$$
#
# This means that:
#
# $$Y_1 = \mu + \epsilon_1+  \theta * \epsilon_{0}$$
# $$Y_2 = \mu + \epsilon_2+  \theta * \epsilon_{1}$$
#
# and so on.
#
# Assume a mean-zero white noise with a standard deviation of 4. Make sure you have a daily datetime index is ranging from April 2015 until the end of August 2015. Assume that $\mu=7$.

# %%
# keep the random seed
np.random.seed(1234)

# create a series with the specified dates
dates = pd.date_range('2015-04-01', '2015-08-31')
len(dates)

# store the parameters
mu = 7
error = np.random.normal(0, 4, len(dates))
theta = 0.9

#generate the time series
TS = [None] * len(dates)
error_previous = error[0]
for i, row in enumerate(dates):
    TS[i] = mu + error[i] + theta * error_previous
    error_previous = error[i]

# %%
# Plot the time series
series =  pd.Series(TS, index=dates)
series.plot(figsize=(14, 4), linewidth=2, fontsize=14);

# %% [markdown]
# ## Look at the ACF and PACF of your model and write down your conclusions

# %%
# plots here
fig, ax = plt.subplots(figsize=(14, 4))
plot_acf(series, ax=ax, lags=40);

fig, ax = plt.subplots(figsize=(14, 4))
plot_pacf(series, ax=ax, lags=40);

# %% [markdown]
# ## Check your model with ARMA in statsmodels

# %% [markdown]
# Repeat what you did for your AR model but now for your MA model to verify the parameters are estimated correctly.

# %%
# Fit an AR(1) model to the first simulated data
mod_arma = ARMA(series, order=(0, 1))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())
print(res_arma.params)
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  153
# Model:                     ARMA(0, 1)   Log Likelihood                -426.378
# Method:                       css-mle   S.D. of innovations              3.909
# Date:                Thu, 07 Nov 2019   AIC                            858.757
# Time:                        13:35:04   BIC                            867.848
# Sample:                    04-01-2015   HQIC                           862.450
#                          - 08-31-2015
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.5373      0.590     12.776      0.000       6.381       8.694
# ma.L1.y        0.8727      0.051     17.165      0.000       0.773       0.972
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.1459           +0.0000j            1.1459            0.5000
# -----------------------------------------------------------------------------
# const      7.537291
# ma.L1.y    0.872683
# dtype: float64

# %% [markdown]
# ## Create a model for the 400m data set

# %% [markdown]
# Import the data set containing the historical running times for the men's 400m on the Olympic games.

# %%
# the data is in "winning_400m.csv"
data = pd.read_csv("winning_400m.csv")
data.year = data.year.astype(str)
data.year = pd.to_datetime(data.year.astype(str))
col_name = 'year'
data.set_index(col_name, inplace=True)

# %% [markdown]
# Plot the data

# %%
# your code here
data.plot(figsize=(12, 4), linewidth=2, fontsize=14)
plt.xlabel(col_name, fontsize=20)
plt.ylabel("400m Winning Times (sec)", fontsize=16);

# %% [markdown]
# Difference the data to get a stationary time series. Make sure to remove the first NaN value.

# %%
# your code here
data_diff = data.diff().dropna()
data_diff
# Out:
#             winning_times
# year
# 1904-01-01           -0.2
# 1908-01-01            0.8
# 1912-01-01           -1.8
# 1920-01-01            1.4
# 1924-01-01           -2.0
# 1928-01-01            0.2
# 1932-01-01           -1.6
# 1936-01-01            0.3
# 1948-01-01           -0.3
# 1952-01-01           -0.3
# 1956-01-01            0.8
# 1960-01-01           -1.8
# 1964-01-01            0.2
# 1968-01-01           -1.3
# 1972-01-01            0.9
# 1976-01-01           -0.4
# 1980-01-01            0.3
# 1984-01-01           -0.3
# 1988-01-01           -0.4
# 1992-01-01           -0.4
# 1996-01-01            0.0

# %%
# Look at ACF and PACF
fig, ax = plt.subplots(figsize=(8, 4))
plot_acf(data_diff, ax=ax, lags=12);

fig, ax = plt.subplots(figsize=(8, 4))
plot_pacf(data_diff, ax=ax, lags=10);

# %% [markdown]
# Based on the ACF and PACF, fit an arma model with the right orders for AR and MA. Feel free to try different models and compare AIC and BIC values, as well as significance values for the parameter estimates.

# %%
# your code here
# ARMA(1, 1)
mod_arma = ARMA(data_diff, order=(1, 1))
res_arma = mod_arma.fit()

# Summary
print(res_arma.summary())
print(res_arma.params)
# Out:
# C:\Users\IBM\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                     ARMA(1, 1)   Log Likelihood                 -19.958
# Method:                       css-mle   S.D. of innovations              0.615
# Date:                Thu, 07 Nov 2019   AIC                             47.916
# Time:                        13:44:14   BIC                             52.094
# Sample:                             0   HQIC                            48.822
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2850      0.086     -3.298      0.004      -0.454      -0.116
# ar.L1.winning_times    -0.7708      0.160     -4.826      0.000      -1.084      -0.458
# ma.L1.winning_times     0.1172      0.254      0.462      0.650      -0.380       0.614
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2974           +0.0000j            1.2974            0.5000
# MA.1           -8.5305           +0.0000j            8.5305            0.5000
# -----------------------------------------------------------------------------
# const                 -0.285012
# ar.L1.winning_times   -0.770752
# ma.L1.winning_times    0.117226
# dtype: float64

# %%
# Try another one
# ARMA(2, 1)
mod_arma = ARMA(data_diff, order=(2, 1))
res_arma = mod_arma.fit()

# Summary
print(res_arma.summary())
print(res_arma.params)
# Out:
# C:\Users\IBM\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                     ARMA(2, 1)   Log Likelihood                 -18.955
# Method:                       css-mle   S.D. of innovations              0.562
# Date:                Thu, 07 Nov 2019   AIC                             47.911
# Time:                        13:44:25   BIC                             53.133
# Sample:                             0   HQIC                            49.044
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2916      0.073     -4.018      0.001      -0.434      -0.149
# ar.L1.winning_times    -1.6827      0.119    -14.199      0.000      -1.915      -1.450
# ar.L2.winning_times    -0.7714      0.128     -6.022      0.000      -1.022      -0.520
# ma.L1.winning_times     0.9999      0.132      7.550      0.000       0.740       1.259
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0907           -0.3268j            1.1386           -0.4537
# AR.2           -1.0907           +0.3268j            1.1386            0.4537
# MA.1           -1.0001           +0.0000j            1.0001            0.5000
# -----------------------------------------------------------------------------
# const                 -0.291565
# ar.L1.winning_times   -1.682690
# ar.L2.winning_times   -0.771404
# ma.L1.winning_times    0.999906
# dtype: float64

# %%
# Try another one
# ARMA(1, 2)
mod_arma = ARMA(data_diff, order=(1, 2))
res_arma = mod_arma.fit()

# Summary
print(res_arma.summary())
print(res_arma.params)
# Out:
# C:\Users\IBM\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                     ARMA(1, 2)   Log Likelihood                 -19.076
# Method:                       css-mle   S.D. of innovations              0.558
# Date:                Thu, 07 Nov 2019   AIC                             48.152
# Time:                        13:44:45   BIC                             53.374
# Sample:                             0   HQIC                            49.285
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2784      0.148     -1.876      0.078      -0.569       0.012
# ar.L1.winning_times    -0.4717      0.261     -1.807      0.088      -0.983       0.040
# ma.L1.winning_times    -0.0096      0.169     -0.057      0.955      -0.341       0.322
# ma.L2.winning_times     0.8467      0.498      1.702      0.107      -0.128       1.822
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.1201           +0.0000j            2.1201            0.5000
# MA.1            0.0057           -1.0867j            1.0867           -0.2492
# MA.2            0.0057           +1.0867j            1.0867            0.2492
# -----------------------------------------------------------------------------
# const                 -0.278384
# ar.L1.winning_times   -0.471669
# ma.L1.winning_times   -0.009634
# ma.L2.winning_times    0.846724
# dtype: float64

# %%
# Try another one
# ARMA(2, 2)
mod_arma = ARMA(data_diff, order=(2, 2))
res_arma = mod_arma.fit()

# Summary
print(res_arma.summary())
print(res_arma.params)
# Out:
# C:\Users\IBM\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                     ARMA(2, 2)   Log Likelihood                 -16.472
# Method:                       css-mle   S.D. of innovations              0.461
# Date:                Thu, 07 Nov 2019   AIC                             44.943
# Time:                        13:45:06   BIC                             51.210
# Sample:                             0   HQIC                            46.303
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2718      0.098     -2.779      0.013      -0.463      -0.080
# ar.L1.winning_times    -1.7575      0.097    -18.070      0.000      -1.948      -1.567
# ar.L2.winning_times    -0.9182      0.092    -10.002      0.000      -1.098      -0.738
# ma.L1.winning_times     1.5682      0.221      7.083      0.000       1.134       2.002
# ma.L2.winning_times     1.0000      0.253      3.951      0.001       0.504       1.496
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.9571           -0.4161j            1.0436           -0.4347
# AR.2           -0.9571           +0.4161j            1.0436            0.4347
# MA.1           -0.7841           -0.6206j            1.0000           -0.3934
# MA.2           -0.7841           +0.6206j            1.0000            0.3934
# -----------------------------------------------------------------------------
# const                 -0.271803
# ar.L1.winning_times   -1.757477
# ar.L2.winning_times   -0.918152
# ma.L1.winning_times    1.568182
# ma.L2.winning_times    1.000000
# dtype: float64

# %% [markdown]
# ## What is your final model? Why did you pick this model?

# %%
# Your comments here
# All of the four models inspected -- ARMA(1, 1), ARMA(1, 2), ARMA(2, 1) and ARMA(2,2) -- provide 
# decent fits with significant parameters. 
# Looking at the AIC and BIC information criterion, the model with the lowest values is ARMA(2, 2).
# This model has a good fit and better parsimony than the other options.

# %% [markdown]
# ## Summary
#
# Great! Now that you know the ins and outs of ARMA models and you've practiced your modeling knowledge.
